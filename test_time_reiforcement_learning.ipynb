# %%
import os
import json
import zipfile
import urllib.request

import numpy as np

RNG = np.random.default_rng(42)

TEXT8_URL     = "http://mattmahoney.net/dc/text8.zip"
TEXT8_PATH    = "text8"
TEXT8_ZIP     = "text8.zip"
ANALOGY_PATH  = "analogies.txt"
ANALOGY_URL   = "https://raw.githubusercontent.com/tmikolov/word2vec/master/questions-words.txt"

def load_text8(path=TEXT8_PATH):
    """
    Loads the Text8 corpus, downloading it automatically if not present.
    Source: http://mattmahoney.net/dc/text8.zip
    """
    if not os.path.exists(path):
        if not os.path.exists(TEXT8_ZIP):
            print("Downloading Text8...")
            urllib.request.urlretrieve(TEXT8_URL, TEXT8_ZIP)
        print("Extracting Text8...")
        with zipfile.ZipFile(TEXT8_ZIP) as zf:
            zf.extractall()
    with open(path) as f:
        return f.read().split()


def load_analogy_dataset(path=ANALOGY_PATH):
    """
    Downloads the original Google word analogy benchmark if not present.
    Contains 19,544 analogies across semantic and syntactic categories.
    Source: https://github.com/tmikolov/word2vec
    """
    if not os.path.exists(path):
        print("Downloading Google analogy benchmark...")
        urllib.request.urlretrieve(ANALOGY_URL, path)
        with open(path, encoding="utf-8") as f:
            n = sum(1 for l in f if not l.startswith(":"))
        print(f"Analogy dataset saved to '{path}' ({n:,} analogies).")
    return path


def build_vocab(tokens, min_count=5):
    """
    Builds vocabulary without the Counter library.
    Keeps only words with frequency >= min_count.
    Sorts by frequency — most frequent words get lowest IDs.
    """
    freq = {}
    for t in tokens:
        freq[t] = freq.get(t, 0) + 1
    freq         = {w: c for w, c in freq.items() if c >= min_count}
    sorted_vocab = sorted(freq.items(), key=lambda x: x[1], reverse=True)
    vocab        = {word: i for i, (word, _) in enumerate(sorted_vocab)}
    id2word      = {i: word for word, i in vocab.items()}
    return vocab, id2word, freq


def subsample(token_ids, freq, id2word, vocab_size, t=1e-5):
    """
    Mikolov subsampling of frequent words.
    P(keep) = sqrt(t / f(w))
    Frequent words (the, a, is) are discarded with high probability.
    """
    total  = sum(freq.values())
    f      = np.array([freq[id2word[i]] / total for i in range(vocab_size)])
    p_keep = np.sqrt(t / (f + 1e-12))
    keep   = p_keep[token_ids] > RNG.random(len(token_ids))
    return np.array(token_ids)[keep].tolist()


def make_noise_dist(freq, vocab, alpha=0.75):
    """
    Unigram^0.75 distribution for negative sampling.
    Exponent 0.75 reduces dominance of frequent words as negatives
    without fully equalising to a uniform distribution.
    """
    counts = np.array([freq[w] for w in vocab], dtype=np.float64)
    probs  = counts ** alpha
    return probs / probs.sum()


def skipgram_pairs_batch(token_ids, window, batch_size):
    """
    Generates (center, context) pairs with a dynamic window.
    c ~ Uniform[1, window] — closer words get a higher effective weight
    because they are included in more pairs than distant words.
    """
    centers, contexts = [], []
    for i, center in enumerate(token_ids): 
        c = RNG.integers(1, window + 1)
        lo, hi = max(0, i - c), min(len(token_ids), i + c + 1)
        
        for j in range(lo, hi):
            if i != j:
                centers.append(center)
                contexts.append(token_ids[j])
                
                if len(centers) == batch_size:
                
                    yield np.array(centers), np.array(contexts), i
                    centers, contexts = [], []
    if centers:
        yield np.array(centers), np.array(contexts), len(token_ids)

def sigmoid(x):
    """Numerically stable sigmoid."""
    return 1 / (1 + np.exp(-np.clip(x, -15, 15)))


def save_model(model, vocab, id2word, path="w2v_model"):
    os.makedirs(path, exist_ok=True)
    np.save(os.path.join(path, "W_in.npy"),  model.W_in)
    np.save(os.path.join(path, "W_out.npy"), model.W_out)
    with open(os.path.join(path, "vocab.json"), "w") as f:
        json.dump({
            "vocab"  : vocab,
            "id2word": {str(k): v for k, v in id2word.items()}
        }, f)
    print(f"Model saved to '{path}/'")


def load_model(path="w2v_model"):
    W_in  = np.load(os.path.join(path, "W_in.npy"))
    W_out = np.load(os.path.join(path, "W_out.npy"))
    with open(os.path.join(path, "vocab.json")) as f:
        data = json.load(f)
    vocab   = data["vocab"]
    id2word = {int(k): v for k, v in data["id2word"].items()}
    model   = Word2Vec(vocab_size=W_in.shape[0], dim=W_in.shape[1])
    model.W_in, model.W_out = W_in, W_out
    print(f"Model loaded from '{path}/'")
    return model, vocab, id2word

class Word2Vec:
    """
    Two embedding matrices:
      W_in  (V, D) — center-word vectors  (used as final word vectors)
      W_out (V, D) — context-word vectors (initialised to zeros)
    """

    def __init__(self, vocab_size, dim=100):
        self.D     = dim
        self.W_in  = (RNG.random((vocab_size, dim)) - 0.5) / dim
        self.W_out = (RNG.random((vocab_size, dim)) - 0.5) / dim

        # Adam optimizer states
        self.m_in  = np.zeros_like(self.W_in)
        self.v_in  = np.zeros_like(self.W_in)
        self.m_out = np.zeros_like(self.W_out)
        self.v_out = np.zeros_like(self.W_out)
        self.t     = 0

    # ── Forward pass + loss ──────────────────────────────────
    def forward_loss_batch(self, centers, contexts, negatives):
        """
        SGNS loss for a batch of B pairs:

          L = -mean_b [ log σ(u_pos·v_c) + Σ_k log σ(-u_neg_k·v_c) ]

        Gradients derived via chain rule through sigmoid:
          ∂L/∂v_c     = (σ(s_pos)-1)·u_pos + Σ_k σ(s_neg_k)·u_neg_k
          ∂L/∂u_pos   = (σ(s_pos)-1)·v_c
          ∂L/∂u_neg_k = σ(s_neg_k)·v_c
        """
        vc    = self.W_in[centers]       # (B, D)
        u_pos = self.W_out[contexts]     # (B, D)
        u_neg = self.W_out[negatives]    # (B, K, D)

        s_pos = np.sum(vc * u_pos, axis=1)             # (B,)
        s_neg = np.einsum('bd,bkd->bk', vc, u_neg)     # (B, K)

        sig_pos = sigmoid(s_pos)
        sig_neg = sigmoid(s_neg)

        eps  = 1e-7
        loss = -np.mean(
            np.log(sig_pos + eps) + np.sum(np.log(1 - sig_neg + eps), axis=1)
        )

        B       = len(centers)
        err_pos = (sig_pos - 1.0) 
        err_neg = sig_neg 

        grad_vc    = err_pos[:, None] * u_pos + np.einsum('bk,bkd->bd', err_neg, u_neg)
        grad_u_pos = err_pos[:, None] * vc
        grad_u_neg = np.einsum('bk,bd->bkd', err_neg, vc)

        return loss, grad_vc, grad_u_pos, grad_u_neg

    # ── SGD update ───────────────────────────────────────────
    def update_batch(self, centers, contexts, negatives, g_vc, g_u_pos, g_u_neg, lr):
        """
        np.add.at accumulates gradients for repeated indices within a batch.
        Plain indexing W_in[centers] -= grad would overwrite duplicates.
        """
        np.add.at(self.W_in,  centers,          -lr * g_vc)
        np.add.at(self.W_out, contexts,          -lr * g_u_pos)
        np.add.at(self.W_out, negatives.ravel(), -lr * g_u_neg.reshape(-1, self.D))


    def update_batch_adam(self, centers, contexts, negatives, g_vc, g_u_pos, g_u_neg, lr):
        """Sparse (Lazy) Adam """
        self.t += 1
        beta1, beta2, eps = 0.9, 0.999, 1e-8

        unique_centers, inverse_centers = np.unique(centers, return_inverse=True)
        grad_W_in = np.zeros((len(unique_centers), self.D))
        np.add.at(grad_W_in, inverse_centers, g_vc)

        self.m_in[unique_centers] = beta1 * self.m_in[unique_centers] + (1 - beta1) * grad_W_in
        self.v_in[unique_centers] = beta2 * self.v_in[unique_centers] + (1 - beta2) * (grad_W_in ** 2)
        
        m_hat_in = self.m_in[unique_centers] / (1 - beta1 ** self.t)
        v_hat_in = self.v_in[unique_centers] / (1 - beta2 ** self.t)
        
        self.W_in[unique_centers] -= lr * m_hat_in / (np.sqrt(v_hat_in) + eps)

        all_out_indices = np.concatenate([contexts, negatives.ravel()])
        all_out_grads   = np.vstack([g_u_pos, g_u_neg.reshape(-1, self.D)])

        unique_out, inverse_out = np.unique(all_out_indices, return_inverse=True)
        grad_W_out = np.zeros((len(unique_out), self.D))
        np.add.at(grad_W_out, inverse_out, all_out_grads)

        self.m_out[unique_out] = beta1 * self.m_out[unique_out] + (1 - beta1) * grad_W_out
        self.v_out[unique_out] = beta2 * self.v_out[unique_out] + (1 - beta2) * (grad_W_out ** 2)
        
        m_hat_out = self.m_out[unique_out] / (1 - beta1 ** self.t)
        v_hat_out = self.v_out[unique_out] / (1 - beta2 ** self.t)
        
        self.W_out[unique_out] -= lr * m_hat_out / (np.sqrt(v_hat_out) + eps)

    # ── Vector evaluation ────────────────────────────────────
    def most_similar(self, word, vocab, id2word, top_n=8):
        """Cosine similarity — top N nearest neighbours."""
        if word not in vocab:
            print(f"  '{word}' not in vocabulary.")
            return
        idx   = vocab[word]
        vec   = self.W_in[idx]
        norms = np.linalg.norm(self.W_in, axis=1)
        sims  = self.W_in @ vec / (norms * np.linalg.norm(vec) + 1e-9)
        sims[idx] = -1
        top = np.argsort(sims)[::-1][:top_n]
        print(f"  Nearest neighbours of '{word}':")
        for i in top:
            print(f"    {id2word[i]:<20s}  {sims[i]:.4f}")

    def analogy(self, a, b, c, vocab, id2word, top_n=1):
        """
        Vector analogy: a - b + c = ?
        Example: king - man + woman = queen
        Tests the linear structure of the embedding space.
        Returns a list of top_n predictions.
        """
        for w in [a, b, c]:
            if w not in vocab:
                return None
        target = self.W_in[vocab[a]] - self.W_in[vocab[b]] + self.W_in[vocab[c]]
        norms  = np.linalg.norm(self.W_in, axis=1)
        sims   = self.W_in @ target / (norms * np.linalg.norm(target) + 1e-9)
        for w in [a, b, c]:
            sims[vocab[w]] = -1
        top = np.argsort(sims)[::-1][:top_n]
        return [id2word[i] for i in top]



def train(token_ids, model, noise_probs, epochs=3, batch_size=512,
          lr_start=0.025, lr_min=0.0001, report_every=100000, optimizer="adam"):
    
    N = len(token_ids)
    total_steps = N * epochs 

    for epoch in range(1, epochs + 1):
        epoch_loss = 0.0
        n_batches = 0
      
        for centers, contexts, word_idx in skipgram_pairs_batch(token_ids, 5, batch_size):
            
            current_total_words = ((epoch - 1) * N) + word_idx
            
            lr = max(lr_start * (1 - current_total_words / total_steps), lr_min)

            B = len(centers)
            negs = RNG.choice(len(noise_probs), size=(B, 5), p=noise_probs)
            loss, g_vc, g_u_pos, g_u_neg = model.forward_loss_batch(centers, contexts, negs)

            if optimizer.lower() == "adam":
                model.update_batch_adam(centers, contexts, negs, g_vc, g_u_pos, g_u_neg, lr)
            else:
                model.update_batch(centers, contexts, negs, g_vc, g_u_pos, g_u_neg, lr)

            epoch_loss += loss
            n_batches += 1
            
            if (n_batches * batch_size) % report_every < batch_size:
                print(f"Epoch {epoch} | Progress: {word_idx/N*100:.1f}% | LR: {lr:.5f} | Loss: {epoch_loss/n_batches:.4f}")

    return model


def evaluate_analogies(model, vocab, id2word, path=ANALOGY_PATH):
    """
    Evaluates analogy accuracy on the local analogy file.

    For each line 'a b c d':
      Predicts top-1 word for  a - b + c
      Correct if prediction == d

    Accuracy = correct / total (skipped = words not in vocabulary)
    """
    if not os.path.exists(path):
        print(f"Analogy file not found at '{path}'.")
        return

    correct = 0
    total   = 0
    skipped = 0

    print("\n" + "=" * 55)
    print("ANALOGY ACCURACY EVALUATION")
    print("=" * 55)

    with open(path, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith(":"):
                continue

            parts = line.split()
            if len(parts) != 4:
                continue

            a, b, c, expected = parts

            if any(w not in vocab for w in [a, b, c, expected]):
                skipped += 1
                continue

            predictions = model.analogy(a, b, c, vocab, id2word, top_n=1)
            if predictions is None:
                skipped += 1
                continue

            if predictions[0] == expected:
                correct += 1
            total += 1

    if total == 0:
        print("  No valid analogies found.")
        return

    print(f"\n  Accuracy : {correct}/{total} = {correct/total*100:.1f}%")
    print(f"  Skipped  : {skipped} (words not in vocabulary)")


if __name__ == "__main__":
    DIM        = 100
    EPOCHS     = 3
    BATCH_SIZE = 512
    MAX_TOKENS = None  # use all tokens
    OPTIMIZER = "adam"
    LR_START = 0.005 # Adam requires lower LR than in original paper

    # ── Generate / download datasets ────────────────────────
    load_analogy_dataset()

    # ── Load Text8 and train ─────────────────────────────────
    print("=" * 55)
    print("Word2Vec SGNS")
    print("=" * 55)

    tokens = load_text8()
    print(f"Corpus     : {len(tokens):,} tokens")

    vocab, id2word, freq = build_vocab(tokens, min_count=5)
    print(f"Vocabulary : {len(vocab):,} words")

    token_ids   = [vocab[t] for t in tokens if t in vocab]
    token_ids   = subsample(token_ids, freq, id2word, len(vocab))

    print(f"After subsampling: {len(token_ids):,} tokens")

    noise_probs = make_noise_dist(freq, vocab)

    model = Word2Vec(vocab_size=len(vocab), dim=DIM)
    print(f"\nTraining ({EPOCHS} epochs, batch={BATCH_SIZE})...\n")
    train(token_ids, model, noise_probs, epochs=EPOCHS, batch_size=BATCH_SIZE, optimizer=OPTIMIZER, lr_start=LR_START)
    save_model(model, vocab, id2word)

    # ── W2V vector evaluation ────────────────────────────────
    print("\n" + "=" * 55)
    print("W2V VECTOR EVALUATION — most similar")
    print("=" * 55)

    # examples
    for word in ["king", "paris", "computer", "music"]:
        model.most_similar(word, vocab, id2word)
        print()

    # ── Analogy accuracy ─────────────────────────────────────
    evaluate_analogies(model, vocab, id2word)
# Out:
# =======================================================
# Word2Vec SGNS
# =======================================================
# Corpus     : 17,005,207 tokens
# Vocabulary : 71,290 words
# After subsampling: 4,668,656 tokens
#
# Training (3 epochs, batch=512)...
#
# Epoch 1 | Progress: 0.4% | LR: 0.00499 | Loss: 4.0123
# Epoch 1 | Progress: 0.7% | LR: 0.00499 | Loss: 3.8400
# Epoch 1 | Progress: 1.1% | LR: 0.00498 | Loss: 3.7192
# Epoch 1 | Progress: 1.4% | LR: 0.00498 | Loss: 3.6335
# Epoch 1 | Progress: 1.8% | LR: 0.00497 | Loss: 3.5627
# Epoch 1 | Progress: 2.1% | LR: 0.00496 | Loss: 3.5114
# Epoch 1 | Progress: 2.5% | LR: 0.00496 | Loss: 3.4731
# Epoch 1 | Progress: 2.9% | LR: 0.00495 | Loss: 3.4386
# Epoch 1 | Progress: 3.2% | LR: 0.00495 | Loss: 3.4178
# Epoch 1 | Progress: 3.6% | LR: 0.00494 | Loss: 3.3959
# Epoch 1 | Progress: 3.9% | LR: 0.00493 | Loss: 3.3772
# Epoch 1 | Progress: 4.3% | LR: 0.00493 | Loss: 3.3562
# Epoch 1 | Progress: 4.6% | LR: 0.00492 | Loss: 3.3391
# Epoch 1 | Progress: 5.0% | LR: 0.00492 | Loss: 3.3218
# Epoch 1 | Progress: 5.4% | LR: 0.00491 | Loss: 3.3068
# Epoch 1 | Progress: 5.7% | LR: 0.00490 | Loss: 3.2933
# Epoch 1 | Progress: 6.1% | LR: 0.00490 | Loss: 3.2754
# Epoch 1 | Progress: 6.4% | LR: 0.00489 | Loss: 3.2575
# Epoch 1 | Progress: 6.8% | LR: 0.00489 | Loss: 3.2425
# Epoch 1 | Progress: 7.1% | LR: 0.00488 | Loss: 3.2335
# Epoch 1 | Progress: 7.5% | LR: 0.00488 | Loss: 3.2243
# Epoch 1 | Progress: 7.8% | LR: 0.00487 | Loss: 3.2127
# Epoch 1 | Progress: 8.2% | LR: 0.00486 | Loss: 3.2009
# Epoch 1 | Progress: 8.6% | LR: 0.00486 | Loss: 3.1955
# Epoch 1 | Progress: 8.9% | LR: 0.00485 | Loss: 3.1867
# Epoch 1 | Progress: 9.3% | LR: 0.00485 | Loss: 3.1793
# Epoch 1 | Progress: 9.6% | LR: 0.00484 | Loss: 3.1745
# Epoch 1 | Progress: 10.0% | LR: 0.00483 | Loss: 3.1689
# Epoch 1 | Progress: 10.4% | LR: 0.00483 | Loss: 3.1637
# Epoch 1 | Progress: 10.7% | LR: 0.00482 | Loss: 3.1554
# Epoch 2 | Progress: 37.1% | LR: 0.00271 | Loss: 2.4221
# Epoch 2 | Progress: 37.5% | LR: 0.00271 | Loss: 2.4222
# Epoch 2 | Progress: 37.8% | LR: 0.00270 | Loss: 2.4221
# Epoch 2 | Progress: 38.2% | LR: 0.00270 | Loss: 2.4215
# Epoch 2 | Progress: 38.5% | LR: 0.00269 | Loss: 2.4210
# Epoch 2 | Progress: 38.9% | LR: 0.00268 | Loss: 2.4211
# Epoch 2 | Progress: 39.3% | LR: 0.00268 | Loss: 2.4207
# Epoch 2 | Progress: 39.6% | LR: 0.00267 | Loss: 2.4205
# Epoch 2 | Progress: 40.0% | LR: 0.00267 | Loss: 2.4201
# Epoch 2 | Progress: 40.3% | LR: 0.00266 | Loss: 2.4202
# Epoch 2 | Progress: 40.7% | LR: 0.00266 | Loss: 2.4205
# Epoch 2 | Progress: 41.0% | LR: 0.00265 | Loss: 2.4204
# Epoch 2 | Progress: 41.4% | LR: 0.00264 | Loss: 2.4205
# Epoch 2 | Progress: 41.8% | LR: 0.00264 | Loss: 2.4207
# Epoch 2 | Progress: 42.1% | LR: 0.00263 | Loss: 2.4204
# Epoch 2 | Progress: 42.5% | LR: 0.00263 | Loss: 2.4203
# Epoch 2 | Progress: 42.8% | LR: 0.00262 | Loss: 2.4198
# Epoch 2 | Progress: 43.2% | LR: 0.00261 | Loss: 2.4194
# Epoch 2 | Progress: 43.5% | LR: 0.00261 | Loss: 2.4185
# Epoch 2 | Progress: 43.9% | LR: 0.00260 | Loss: 2.4182
# Epoch 2 | Progress: 44.3% | LR: 0.00260 | Loss: 2.4182
# Epoch 2 | Progress: 44.6% | LR: 0.00259 | Loss: 2.4176
# Epoch 2 | Progress: 45.0% | LR: 0.00258 | Loss: 2.4169
# Epoch 2 | Progress: 45.3% | LR: 0.00258 | Loss: 2.4163
# Epoch 2 | Progress: 45.7% | LR: 0.00257 | Loss: 2.4161
# Epoch 2 | Progress: 46.0% | LR: 0.00257 | Loss: 2.4158
# Epoch 2 | Progress: 46.4% | LR: 0.00256 | Loss: 2.4155
# Epoch 2 | Progress: 46.8% | LR: 0.00255 | Loss: 2.4151
# Epoch 2 | Progress: 47.1% | LR: 0.00255 | Loss: 2.4149
# Epoch 2 | Progress: 47.5% | LR: 0.00254 | Loss: 2.4145
# Epoch 2 | Progress: 47.8% | LR: 0.00254 | Loss: 2.4142
# Epoch 2 | Progress: 48.2% | LR: 0.00253 | Loss: 2.4141
# Epoch 2 | Progress: 48.5% | LR: 0.00252 | Loss: 2.4140
# Epoch 2 | Progress: 48.9% | LR: 0.00252 | Loss: 2.4141
# Epoch 2 | Progress: 49.3% | LR: 0.00251 | Loss: 2.4139
# Epoch 2 | Progress: 49.6% | LR: 0.00251 | Loss: 2.4133
# Epoch 2 | Progress: 50.0% | LR: 0.00250 | Loss: 2.4133
# Epoch 2 | Progress: 50.3% | LR: 0.00249 | Loss: 2.4131
# Epoch 2 | Progress: 50.7% | LR: 0.00249 | Loss: 2.4127
# Epoch 2 | Progress: 65.3% | LR: 0.00224 | Loss: 2.4040
# Epoch 2 | Progress: 65.7% | LR: 0.00224 | Loss: 2.4038
# Epoch 2 | Progress: 66.0% | LR: 0.00223 | Loss: 2.4035
# Epoch 2 | Progress: 66.4% | LR: 0.00223 | Loss: 2.4033
# Epoch 2 | Progress: 66.7% | LR: 0.00222 | Loss: 2.4033
# Epoch 2 | Progress: 67.1% | LR: 0.00221 | Loss: 2.4031
# Epoch 2 | Progress: 67.5% | LR: 0.00221 | Loss: 2.4028
# Epoch 2 | Progress: 67.8% | LR: 0.00220 | Loss: 2.4026
# Epoch 2 | Progress: 68.2% | LR: 0.00220 | Loss: 2.4025
# Epoch 2 | Progress: 68.5% | LR: 0.00219 | Loss: 2.4021
# Epoch 2 | Progress: 68.9% | LR: 0.00219 | Loss: 2.4018
# Epoch 2 | Progress: 69.2% | LR: 0.00218 | Loss: 2.4016
# Epoch 2 | Progress: 69.6% | LR: 0.00217 | Loss: 2.4015
# Epoch 2 | Progress: 70.0% | LR: 0.00217 | Loss: 2.4008
# Epoch 2 | Progress: 70.3% | LR: 0.00216 | Loss: 2.4006
# Epoch 2 | Progress: 70.7% | LR: 0.00216 | Loss: 2.4003
# Epoch 2 | Progress: 71.0% | LR: 0.00215 | Loss: 2.3999
# Epoch 2 | Progress: 71.4% | LR: 0.00214 | Loss: 2.3995
# Epoch 2 | Progress: 71.8% | LR: 0.00214 | Loss: 2.3991
# Epoch 2 | Progress: 72.1% | LR: 0.00213 | Loss: 2.3990
# Epoch 2 | Progress: 72.5% | LR: 0.00213 | Loss: 2.3989
# Epoch 2 | Progress: 72.8% | LR: 0.00212 | Loss: 2.3986
# Epoch 2 | Progress: 73.2% | LR: 0.00211 | Loss: 2.3982
# Epoch 2 | Progress: 73.5% | LR: 0.00211 | Loss: 2.3979
# Epoch 2 | Progress: 73.9% | LR: 0.00210 | Loss: 2.3974
# Epoch 2 | Progress: 74.3% | LR: 0.00210 | Loss: 2.3977
# Epoch 2 | Progress: 74.6% | LR: 0.00209 | Loss: 2.3979
# Epoch 2 | Progress: 75.0% | LR: 0.00208 | Loss: 2.3976
# Epoch 2 | Progress: 75.3% | LR: 0.00208 | Loss: 2.3972
# Epoch 2 | Progress: 75.7% | LR: 0.00207 | Loss: 2.3967
# Epoch 2 | Progress: 76.0% | LR: 0.00207 | Loss: 2.3963
# Epoch 2 | Progress: 76.4% | LR: 0.00206 | Loss: 2.3961
# Epoch 2 | Progress: 76.8% | LR: 0.00205 | Loss: 2.3956
# Epoch 2 | Progress: 77.1% | LR: 0.00205 | Loss: 2.3954
# Epoch 2 | Progress: 77.5% | LR: 0.00204 | Loss: 2.3953
# Epoch 2 | Progress: 77.8% | LR: 0.00204 | Loss: 2.3950
# Epoch 2 | Progress: 78.2% | LR: 0.00203 | Loss: 2.3950
# Epoch 2 | Progress: 78.5% | LR: 0.00202 | Loss: 2.3950
# Epoch 2 | Progress: 78.9% | LR: 0.00202 | Loss: 2.3950
# Epoch 2 | Progress: 93.2% | LR: 0.00178 | Loss: 2.3883
# Epoch 2 | Progress: 93.5% | LR: 0.00177 | Loss: 2.3881
# Epoch 2 | Progress: 93.9% | LR: 0.00177 | Loss: 2.3877
# Epoch 2 | Progress: 94.2% | LR: 0.00176 | Loss: 2.3875
# Epoch 2 | Progress: 94.6% | LR: 0.00176 | Loss: 2.3874
# Epoch 2 | Progress: 94.9% | LR: 0.00175 | Loss: 2.3872
# Epoch 2 | Progress: 95.3% | LR: 0.00174 | Loss: 2.3871
# Epoch 2 | Progress: 95.7% | LR: 0.00174 | Loss: 2.3868
# Epoch 2 | Progress: 96.0% | LR: 0.00173 | Loss: 2.3868
# Epoch 2 | Progress: 96.4% | LR: 0.00173 | Loss: 2.3866
# Epoch 2 | Progress: 96.7% | LR: 0.00172 | Loss: 2.3864
# Epoch 2 | Progress: 97.1% | LR: 0.00172 | Loss: 2.3861
# Epoch 2 | Progress: 97.5% | LR: 0.00171 | Loss: 2.3859
# Epoch 2 | Progress: 97.8% | LR: 0.00170 | Loss: 2.3857
# Epoch 2 | Progress: 98.2% | LR: 0.00170 | Loss: 2.3857
# Epoch 2 | Progress: 98.5% | LR: 0.00169 | Loss: 2.3855
# Epoch 2 | Progress: 98.9% | LR: 0.00169 | Loss: 2.3854
# Epoch 2 | Progress: 99.2% | LR: 0.00168 | Loss: 2.3854
# Epoch 2 | Progress: 99.6% | LR: 0.00167 | Loss: 2.3855
# Epoch 2 | Progress: 100.0% | LR: 0.00167 | Loss: 2.3853
# Epoch 3 | Progress: 0.4% | LR: 0.00166 | Loss: 2.3321
# Epoch 3 | Progress: 0.7% | LR: 0.00165 | Loss: 2.3454
# Epoch 3 | Progress: 1.1% | LR: 0.00165 | Loss: 2.3380
# Epoch 3 | Progress: 1.4% | LR: 0.00164 | Loss: 2.3212
# Epoch 3 | Progress: 1.8% | LR: 0.00164 | Loss: 2.3249
# Epoch 3 | Progress: 2.1% | LR: 0.00163 | Loss: 2.3254
# Epoch 3 | Progress: 2.5% | LR: 0.00162 | Loss: 2.3305
# Epoch 3 | Progress: 2.9% | LR: 0.00162 | Loss: 2.3223
# Epoch 3 | Progress: 3.2% | LR: 0.00161 | Loss: 2.3188
# Epoch 3 | Progress: 3.6% | LR: 0.00161 | Loss: 2.3136
# Epoch 3 | Progress: 3.9% | LR: 0.00160 | Loss: 2.3138
# Epoch 3 | Progress: 4.3% | LR: 0.00160 | Loss: 2.3152
# Epoch 3 | Progress: 4.6% | LR: 0.00159 | Loss: 2.3140
# Epoch 3 | Progress: 5.0% | LR: 0.00158 | Loss: 2.3122
# Epoch 3 | Progress: 5.4% | LR: 0.00158 | Loss: 2.3103
# Epoch 3 | Progress: 5.7% | LR: 0.00157 | Loss: 2.3060
# Epoch 3 | Progress: 6.1% | LR: 0.00157 | Loss: 2.3058
# Epoch 3 | Progress: 6.4% | LR: 0.00156 | Loss: 2.3053
# Epoch 3 | Progress: 6.8% | LR: 0.00155 | Loss: 2.3050
# Epoch 3 | Progress: 7.1% | LR: 0.00155 | Loss: 2.3045
# Epoch 3 | Progress: 7.5% | LR: 0.00154 | Loss: 2.3052
# Epoch 3 | Progress: 7.9% | LR: 0.00154 | Loss: 2.3052
# Epoch 3 | Progress: 8.2% | LR: 0.00153 | Loss: 2.3069
# Epoch 3 | Progress: 8.6% | LR: 0.00152 | Loss: 2.3053
# Epoch 3 | Progress: 8.9% | LR: 0.00152 | Loss: 2.3046
# Epoch 3 | Progress: 9.3% | LR: 0.00151 | Loss: 2.3035
# Epoch 3 | Progress: 9.6% | LR: 0.00151 | Loss: 2.3033
# Epoch 3 | Progress: 10.0% | LR: 0.00150 | Loss: 2.3018
# Epoch 3 | Progress: 10.4% | LR: 0.00149 | Loss: 2.3016
# Epoch 3 | Progress: 10.7% | LR: 0.00149 | Loss: 2.3023
# Epoch 3 | Progress: 11.1% | LR: 0.00148 | Loss: 2.3009
# Epoch 3 | Progress: 11.4% | LR: 0.00148 | Loss: 2.3000
# Epoch 3 | Progress: 11.8% | LR: 0.00147 | Loss: 2.3002
# Epoch 3 | Progress: 12.1% | LR: 0.00146 | Loss: 2.3010
# Epoch 3 | Progress: 12.5% | LR: 0.00146 | Loss: 2.3000
# Epoch 3 | Progress: 12.9% | LR: 0.00145 | Loss: 2.2999
# Epoch 3 | Progress: 13.2% | LR: 0.00145 | Loss: 2.2991
# Epoch 3 | Progress: 13.6% | LR: 0.00144 | Loss: 2.2999
# Epoch 3 | Progress: 13.9% | LR: 0.00143 | Loss: 2.2997
# Epoch 3 | Progress: 14.3% | LR: 0.00143 | Loss: 2.2976
# Epoch 3 | Progress: 14.6% | LR: 0.00142 | Loss: 2.2938
# Epoch 3 | Progress: 15.0% | LR: 0.00142 | Loss: 2.2944
# Epoch 3 | Progress: 15.4% | LR: 0.00141 | Loss: 2.2954
# Epoch 3 | Progress: 15.7% | LR: 0.00140 | Loss: 2.2949
# Epoch 3 | Progress: 16.1% | LR: 0.00140 | Loss: 2.2949
# Epoch 3 | Progress: 16.4% | LR: 0.00139 | Loss: 2.2952
# Epoch 3 | Progress: 16.8% | LR: 0.00139 | Loss: 2.2961
# Epoch 3 | Progress: 17.1% | LR: 0.00138 | Loss: 2.2962
# Epoch 3 | Progress: 17.5% | LR: 0.00138 | Loss: 2.2959
# Epoch 3 | Progress: 17.8% | LR: 0.00137 | Loss: 2.2963
# Epoch 3 | Progress: 18.2% | LR: 0.00136 | Loss: 2.2960
# Epoch 3 | Progress: 18.6% | LR: 0.00136 | Loss: 2.2966
# Epoch 3 | Progress: 18.9% | LR: 0.00135 | Loss: 2.2969
# Epoch 3 | Progress: 19.3% | LR: 0.00135 | Loss: 2.2971
# Epoch 3 | Progress: 19.6% | LR: 0.00134 | Loss: 2.2969
# Epoch 3 | Progress: 20.0% | LR: 0.00133 | Loss: 2.2965
# Epoch 3 | Progress: 20.3% | LR: 0.00133 | Loss: 2.2970
# Epoch 3 | Progress: 20.7% | LR: 0.00132 | Loss: 2.2968
# Epoch 3 | Progress: 21.1% | LR: 0.00132 | Loss: 2.2976
# Epoch 3 | Progress: 21.4% | LR: 0.00131 | Loss: 2.2981
# Epoch 3 | Progress: 21.8% | LR: 0.00130 | Loss: 2.2982
# Epoch 3 | Progress: 22.1% | LR: 0.00130 | Loss: 2.2988
# Epoch 3 | Progress: 22.5% | LR: 0.00129 | Loss: 2.2984
# Epoch 3 | Progress: 22.8% | LR: 0.00129 | Loss: 2.2984
# Epoch 3 | Progress: 23.2% | LR: 0.00128 | Loss: 2.2980
# Epoch 3 | Progress: 23.6% | LR: 0.00127 | Loss: 2.2973
# Epoch 3 | Progress: 23.9% | LR: 0.00127 | Loss: 2.2967
# Epoch 3 | Progress: 24.3% | LR: 0.00126 | Loss: 2.2947
# Epoch 3 | Progress: 24.6% | LR: 0.00126 | Loss: 2.2934
# Epoch 3 | Progress: 25.0% | LR: 0.00125 | Loss: 2.2928
# Epoch 3 | Progress: 25.3% | LR: 0.00124 | Loss: 2.2919
# Epoch 3 | Progress: 25.7% | LR: 0.00124 | Loss: 2.2924
# Epoch 3 | Progress: 26.1% | LR: 0.00123 | Loss: 2.2925
# Epoch 3 | Progress: 26.4% | LR: 0.00123 | Loss: 2.2915
# Epoch 3 | Progress: 26.8% | LR: 0.00122 | Loss: 2.2911
# Epoch 3 | Progress: 27.1% | LR: 0.00121 | Loss: 2.2912
# Epoch 3 | Progress: 27.5% | LR: 0.00121 | Loss: 2.2904
# Epoch 3 | Progress: 27.8% | LR: 0.00120 | Loss: 2.2898
# Epoch 3 | Progress: 28.2% | LR: 0.00120 | Loss: 2.2896
# Epoch 3 | Progress: 28.6% | LR: 0.00119 | Loss: 2.2895
# Epoch 3 | Progress: 28.9% | LR: 0.00118 | Loss: 2.2893
# Epoch 3 | Progress: 29.3% | LR: 0.00118 | Loss: 2.2889
# Epoch 3 | Progress: 29.6% | LR: 0.00117 | Loss: 2.2878
# Epoch 3 | Progress: 30.0% | LR: 0.00117 | Loss: 2.2873
# Epoch 3 | Progress: 30.3% | LR: 0.00116 | Loss: 2.2868
# Epoch 3 | Progress: 30.7% | LR: 0.00115 | Loss: 2.2865
# Epoch 3 | Progress: 31.1% | LR: 0.00115 | Loss: 2.2865
# Epoch 3 | Progress: 31.4% | LR: 0.00114 | Loss: 2.2863
# Epoch 3 | Progress: 31.8% | LR: 0.00114 | Loss: 2.2864
# Epoch 3 | Progress: 32.1% | LR: 0.00113 | Loss: 2.2862
# Epoch 3 | Progress: 32.5% | LR: 0.00113 | Loss: 2.2862
# Epoch 3 | Progress: 32.8% | LR: 0.00112 | Loss: 2.2860
# Epoch 3 | Progress: 33.2% | LR: 0.00111 | Loss: 2.2861
# Epoch 3 | Progress: 33.6% | LR: 0.00111 | Loss: 2.2861
# Epoch 3 | Progress: 33.9% | LR: 0.00110 | Loss: 2.2861
# Epoch 3 | Progress: 34.3% | LR: 0.00110 | Loss: 2.2863
# Epoch 3 | Progress: 34.6% | LR: 0.00109 | Loss: 2.2862
# Epoch 3 | Progress: 35.0% | LR: 0.00108 | Loss: 2.2860
# Epoch 3 | Progress: 35.3% | LR: 0.00108 | Loss: 2.2861
# Epoch 3 | Progress: 35.7% | LR: 0.00107 | Loss: 2.2860
# Epoch 3 | Progress: 36.1% | LR: 0.00107 | Loss: 2.2864
# Epoch 3 | Progress: 36.4% | LR: 0.00106 | Loss: 2.2861
# Epoch 3 | Progress: 36.8% | LR: 0.00105 | Loss: 2.2852
# Epoch 3 | Progress: 37.1% | LR: 0.00105 | Loss: 2.2850
# Epoch 3 | Progress: 37.5% | LR: 0.00104 | Loss: 2.2852
# Epoch 3 | Progress: 37.8% | LR: 0.00104 | Loss: 2.2853
# Epoch 3 | Progress: 38.2% | LR: 0.00103 | Loss: 2.2850
# Epoch 3 | Progress: 38.6% | LR: 0.00102 | Loss: 2.2845
# Epoch 3 | Progress: 38.9% | LR: 0.00102 | Loss: 2.2847
# Epoch 3 | Progress: 39.3% | LR: 0.00101 | Loss: 2.2845
# Epoch 3 | Progress: 39.6% | LR: 0.00101 | Loss: 2.2845
# Epoch 3 | Progress: 40.0% | LR: 0.00100 | Loss: 2.2841
# Epoch 3 | Progress: 40.3% | LR: 0.00099 | Loss: 2.2844
# Epoch 3 | Progress: 40.7% | LR: 0.00099 | Loss: 2.2849
# Epoch 3 | Progress: 41.1% | LR: 0.00098 | Loss: 2.2849
# Epoch 3 | Progress: 41.4% | LR: 0.00098 | Loss: 2.2853
# Epoch 3 | Progress: 41.8% | LR: 0.00097 | Loss: 2.2856
# Epoch 3 | Progress: 42.1% | LR: 0.00096 | Loss: 2.2854
# Epoch 3 | Progress: 42.5% | LR: 0.00096 | Loss: 2.2856
# Epoch 3 | Progress: 42.8% | LR: 0.00095 | Loss: 2.2852
# Epoch 3 | Progress: 43.2% | LR: 0.00095 | Loss: 2.2851
# Epoch 3 | Progress: 43.6% | LR: 0.00094 | Loss: 2.2842
# Epoch 3 | Progress: 43.9% | LR: 0.00093 | Loss: 2.2842
# Epoch 3 | Progress: 44.3% | LR: 0.00093 | Loss: 2.2843
# Epoch 3 | Progress: 44.6% | LR: 0.00092 | Loss: 2.2839
# Epoch 3 | Progress: 45.0% | LR: 0.00092 | Loss: 2.2834
# Epoch 3 | Progress: 45.3% | LR: 0.00091 | Loss: 2.2830
# Epoch 3 | Progress: 45.7% | LR: 0.00090 | Loss: 2.2829
# Epoch 3 | Progress: 46.1% | LR: 0.00090 | Loss: 2.2828
# Epoch 3 | Progress: 46.4% | LR: 0.00089 | Loss: 2.2828
# Epoch 3 | Progress: 46.8% | LR: 0.00089 | Loss: 2.2825
# Epoch 3 | Progress: 47.1% | LR: 0.00088 | Loss: 2.2825
# Epoch 3 | Progress: 47.5% | LR: 0.00088 | Loss: 2.2822
# Epoch 3 | Progress: 47.8% | LR: 0.00087 | Loss: 2.2820
# Epoch 3 | Progress: 48.2% | LR: 0.00086 | Loss: 2.2821
# Epoch 3 | Progress: 48.6% | LR: 0.00086 | Loss: 2.2821
# Epoch 3 | Progress: 48.9% | LR: 0.00085 | Loss: 2.2824
# Epoch 3 | Progress: 49.3% | LR: 0.00085 | Loss: 2.2822
# Epoch 3 | Progress: 49.6% | LR: 0.00084 | Loss: 2.2817
# Epoch 3 | Progress: 50.0% | LR: 0.00083 | Loss: 2.2821
# Epoch 3 | Progress: 50.3% | LR: 0.00083 | Loss: 2.2821
# Epoch 3 | Progress: 50.7% | LR: 0.00082 | Loss: 2.2818
# Epoch 3 | Progress: 51.1% | LR: 0.00082 | Loss: 2.2817
# Epoch 3 | Progress: 51.4% | LR: 0.00081 | Loss: 2.2815
# Epoch 3 | Progress: 51.8% | LR: 0.00080 | Loss: 2.2814
# Epoch 3 | Progress: 52.1% | LR: 0.00080 | Loss: 2.2814
# Epoch 3 | Progress: 52.5% | LR: 0.00079 | Loss: 2.2819
# Epoch 3 | Progress: 52.8% | LR: 0.00079 | Loss: 2.2820
# Epoch 3 | Progress: 53.2% | LR: 0.00078 | Loss: 2.2812
# Epoch 3 | Progress: 53.6% | LR: 0.00077 | Loss: 2.2807
# Epoch 3 | Progress: 53.9% | LR: 0.00077 | Loss: 2.2808
# Epoch 3 | Progress: 54.3% | LR: 0.00076 | Loss: 2.2808
# Epoch 3 | Progress: 54.6% | LR: 0.00076 | Loss: 2.2807
# Epoch 3 | Progress: 55.0% | LR: 0.00075 | Loss: 2.2809
# Epoch 3 | Progress: 55.3% | LR: 0.00074 | Loss: 2.2811
# Epoch 3 | Progress: 55.7% | LR: 0.00074 | Loss: 2.2806
# Epoch 3 | Progress: 56.1% | LR: 0.00073 | Loss: 2.2806
# Epoch 3 | Progress: 56.4% | LR: 0.00073 | Loss: 2.2808
# Epoch 3 | Progress: 56.8% | LR: 0.00072 | Loss: 2.2803
# Epoch 3 | Progress: 57.1% | LR: 0.00071 | Loss: 2.2796
# Epoch 3 | Progress: 57.5% | LR: 0.00071 | Loss: 2.2799
# Epoch 3 | Progress: 57.8% | LR: 0.00070 | Loss: 2.2801
# Epoch 3 | Progress: 58.2% | LR: 0.00070 | Loss: 2.2800
# Epoch 3 | Progress: 58.6% | LR: 0.00069 | Loss: 2.2800
# Epoch 3 | Progress: 58.9% | LR: 0.00068 | Loss: 2.2802
# Epoch 3 | Progress: 59.3% | LR: 0.00068 | Loss: 2.2799
# Epoch 3 | Progress: 59.6% | LR: 0.00067 | Loss: 2.2797
# Epoch 3 | Progress: 60.0% | LR: 0.00067 | Loss: 2.2797
# Epoch 3 | Progress: 60.3% | LR: 0.00066 | Loss: 2.2798
# Epoch 3 | Progress: 60.7% | LR: 0.00065 | Loss: 2.2798
# Epoch 3 | Progress: 61.1% | LR: 0.00065 | Loss: 2.2799
# Epoch 3 | Progress: 61.4% | LR: 0.00064 | Loss: 2.2802
# Epoch 3 | Progress: 61.8% | LR: 0.00064 | Loss: 2.2803
# Epoch 3 | Progress: 62.1% | LR: 0.00063 | Loss: 2.2802
# Epoch 3 | Progress: 62.5% | LR: 0.00063 | Loss: 2.2797
# Epoch 3 | Progress: 62.8% | LR: 0.00062 | Loss: 2.2797
# Epoch 3 | Progress: 63.2% | LR: 0.00061 | Loss: 2.2799
# Epoch 3 | Progress: 63.6% | LR: 0.00061 | Loss: 2.2799
# Epoch 3 | Progress: 63.9% | LR: 0.00060 | Loss: 2.2801
# Epoch 3 | Progress: 64.3% | LR: 0.00060 | Loss: 2.2798
# Epoch 3 | Progress: 64.6% | LR: 0.00059 | Loss: 2.2800
# Epoch 3 | Progress: 65.0% | LR: 0.00058 | Loss: 2.2800
# Epoch 3 | Progress: 65.3% | LR: 0.00058 | Loss: 2.2798
# Epoch 3 | Progress: 65.7% | LR: 0.00057 | Loss: 2.2797
# Epoch 3 | Progress: 66.1% | LR: 0.00057 | Loss: 2.2797
# Epoch 3 | Progress: 66.4% | LR: 0.00056 | Loss: 2.2796
# Epoch 3 | Progress: 66.8% | LR: 0.00055 | Loss: 2.2797
# Epoch 3 | Progress: 67.1% | LR: 0.00055 | Loss: 2.2798
# Epoch 3 | Progress: 67.5% | LR: 0.00054 | Loss: 2.2795
# Epoch 3 | Progress: 67.8% | LR: 0.00054 | Loss: 2.2796
# Epoch 3 | Progress: 68.2% | LR: 0.00053 | Loss: 2.2795
# Epoch 3 | Progress: 68.5% | LR: 0.00052 | Loss: 2.2792
# Epoch 3 | Progress: 68.9% | LR: 0.00052 | Loss: 2.2790
# Epoch 3 | Progress: 69.3% | LR: 0.00051 | Loss: 2.2790
# Epoch 3 | Progress: 69.6% | LR: 0.00051 | Loss: 2.2790
# Epoch 3 | Progress: 70.0% | LR: 0.00050 | Loss: 2.2785
# Epoch 3 | Progress: 70.3% | LR: 0.00049 | Loss: 2.2785
# Epoch 3 | Progress: 70.7% | LR: 0.00049 | Loss: 2.2784
# Epoch 3 | Progress: 71.0% | LR: 0.00048 | Loss: 2.2782
# Epoch 3 | Progress: 71.4% | LR: 0.00048 | Loss: 2.2779
# Epoch 3 | Progress: 71.8% | LR: 0.00047 | Loss: 2.2777
# Epoch 3 | Progress: 72.1% | LR: 0.00046 | Loss: 2.2776
# Epoch 3 | Progress: 72.5% | LR: 0.00046 | Loss: 2.2777
# Epoch 3 | Progress: 72.8% | LR: 0.00045 | Loss: 2.2776
# Epoch 3 | Progress: 73.2% | LR: 0.00045 | Loss: 2.2774
# Epoch 3 | Progress: 73.5% | LR: 0.00044 | Loss: 2.2772
# Epoch 3 | Progress: 73.9% | LR: 0.00044 | Loss: 2.2770
# Epoch 3 | Progress: 74.3% | LR: 0.00043 | Loss: 2.2774
# Epoch 3 | Progress: 74.6% | LR: 0.00042 | Loss: 2.2777
# Epoch 3 | Progress: 75.0% | LR: 0.00042 | Loss: 2.2776
# Epoch 3 | Progress: 75.3% | LR: 0.00041 | Loss: 2.2773
# Epoch 3 | Progress: 75.7% | LR: 0.00041 | Loss: 2.2771
# Epoch 3 | Progress: 76.0% | LR: 0.00040 | Loss: 2.2767
# Epoch 3 | Progress: 76.4% | LR: 0.00039 | Loss: 2.2767
# Epoch 3 | Progress: 76.8% | LR: 0.00039 | Loss: 2.2765
# Epoch 3 | Progress: 77.1% | LR: 0.00038 | Loss: 2.2765
# Epoch 3 | Progress: 77.5% | LR: 0.00038 | Loss: 2.2766
# Epoch 3 | Progress: 77.8% | LR: 0.00037 | Loss: 2.2765
# Epoch 3 | Progress: 78.2% | LR: 0.00036 | Loss: 2.2768
# Epoch 3 | Progress: 78.5% | LR: 0.00036 | Loss: 2.2769
# Epoch 3 | Progress: 78.9% | LR: 0.00035 | Loss: 2.2772
# Epoch 3 | Progress: 79.3% | LR: 0.00035 | Loss: 2.2775
# Epoch 3 | Progress: 79.6% | LR: 0.00034 | Loss: 2.2780
# Epoch 3 | Progress: 80.0% | LR: 0.00033 | Loss: 2.2777
# Epoch 3 | Progress: 80.3% | LR: 0.00033 | Loss: 2.2775
# Epoch 3 | Progress: 80.7% | LR: 0.00032 | Loss: 2.2778
# Epoch 3 | Progress: 81.0% | LR: 0.00032 | Loss: 2.2779
# Epoch 3 | Progress: 81.4% | LR: 0.00031 | Loss: 2.2781
# Epoch 3 | Progress: 81.8% | LR: 0.00030 | Loss: 2.2783
# Epoch 3 | Progress: 82.1% | LR: 0.00030 | Loss: 2.2784
# Epoch 3 | Progress: 82.5% | LR: 0.00029 | Loss: 2.2787
# Epoch 3 | Progress: 82.8% | LR: 0.00029 | Loss: 2.2789
# Epoch 3 | Progress: 83.2% | LR: 0.00028 | Loss: 2.2790
# Epoch 3 | Progress: 83.5% | LR: 0.00027 | Loss: 2.2790
# Epoch 3 | Progress: 83.9% | LR: 0.00027 | Loss: 2.2790
# Epoch 3 | Progress: 84.2% | LR: 0.00026 | Loss: 2.2788
# Epoch 3 | Progress: 84.6% | LR: 0.00026 | Loss: 2.2781
# Epoch 3 | Progress: 85.0% | LR: 0.00025 | Loss: 2.2783
# Epoch 3 | Progress: 85.3% | LR: 0.00024 | Loss: 2.2783
# Epoch 3 | Progress: 85.7% | LR: 0.00024 | Loss: 2.2780
# Epoch 3 | Progress: 86.0% | LR: 0.00023 | Loss: 2.2782
# Epoch 3 | Progress: 86.4% | LR: 0.00023 | Loss: 2.2779
# Epoch 3 | Progress: 86.7% | LR: 0.00022 | Loss: 2.2777
# Epoch 3 | Progress: 87.1% | LR: 0.00021 | Loss: 2.2777
# Epoch 3 | Progress: 87.5% | LR: 0.00021 | Loss: 2.2778
# Epoch 3 | Progress: 87.8% | LR: 0.00020 | Loss: 2.2774
# Epoch 3 | Progress: 88.2% | LR: 0.00020 | Loss: 2.2773
# Epoch 3 | Progress: 88.5% | LR: 0.00019 | Loss: 2.2772
# Epoch 3 | Progress: 88.9% | LR: 0.00019 | Loss: 2.2775
# Epoch 3 | Progress: 89.2% | LR: 0.00018 | Loss: 2.2775
# Epoch 3 | Progress: 89.6% | LR: 0.00017 | Loss: 2.2773
# Epoch 3 | Progress: 90.0% | LR: 0.00017 | Loss: 2.2772
# Epoch 3 | Progress: 90.3% | LR: 0.00016 | Loss: 2.2772
# Epoch 3 | Progress: 90.7% | LR: 0.00016 | Loss: 2.2768
# Epoch 3 | Progress: 91.0% | LR: 0.00015 | Loss: 2.2763
# Epoch 3 | Progress: 91.4% | LR: 0.00014 | Loss: 2.2758
# Epoch 3 | Progress: 91.7% | LR: 0.00014 | Loss: 2.2755
# Epoch 3 | Progress: 92.1% | LR: 0.00013 | Loss: 2.2754
# Epoch 3 | Progress: 92.5% | LR: 0.00013 | Loss: 2.2754
# Epoch 3 | Progress: 92.8% | LR: 0.00012 | Loss: 2.2754
# Epoch 3 | Progress: 93.2% | LR: 0.00011 | Loss: 2.2753
# Epoch 3 | Progress: 93.5% | LR: 0.00011 | Loss: 2.2752
# Epoch 3 | Progress: 93.9% | LR: 0.00010 | Loss: 2.2750
# Epoch 3 | Progress: 94.2% | LR: 0.00010 | Loss: 2.2749
# Epoch 3 | Progress: 94.6% | LR: 0.00010 | Loss: 2.2749
# Epoch 3 | Progress: 95.0% | LR: 0.00010 | Loss: 2.2748
# Epoch 3 | Progress: 95.3% | LR: 0.00010 | Loss: 2.2748
# Epoch 3 | Progress: 95.7% | LR: 0.00010 | Loss: 2.2746
# Epoch 3 | Progress: 96.0% | LR: 0.00010 | Loss: 2.2747
# Epoch 3 | Progress: 96.4% | LR: 0.00010 | Loss: 2.2747
# Epoch 3 | Progress: 96.7% | LR: 0.00010 | Loss: 2.2746
# Epoch 3 | Progress: 97.1% | LR: 0.00010 | Loss: 2.2745
# Epoch 3 | Progress: 97.5% | LR: 0.00010 | Loss: 2.2743
# Epoch 3 | Progress: 97.8% | LR: 0.00010 | Loss: 2.2744
# Epoch 3 | Progress: 98.2% | LR: 0.00010 | Loss: 2.2745
# Epoch 3 | Progress: 98.5% | LR: 0.00010 | Loss: 2.2744
# Epoch 3 | Progress: 98.9% | LR: 0.00010 | Loss: 2.2744
# Epoch 3 | Progress: 99.2% | LR: 0.00010 | Loss: 2.2746
# Epoch 3 | Progress: 99.6% | LR: 0.00010 | Loss: 2.2748
# Epoch 3 | Progress: 100.0% | LR: 0.00010 | Loss: 2.2748
# Model saved to 'w2v_model/'
#
# =======================================================
# W2V VECTOR EVALUATION — most similar
# =======================================================
#   Nearest neighbours of 'king':
#     throne                0.8073
#     vii                   0.7944
#     kings                 0.7669
#     prince                0.7667
#     crowned               0.7659
#     reigned               0.7637
#     grandson              0.7604
#     queen                 0.7466
#
#   Nearest neighbours of 'paris':
#     bologna               0.7669
#     villa                 0.7403
#     seine                 0.7314
#     cimeti                0.7297
#     venice                0.7066
#     lyc                   0.7034
#     duc                   0.7028
#     sainte                0.6982
#
#   Nearest neighbours of 'computer':
#     computing             0.8217
#     computers             0.8127
#     hardware              0.8039
#     graphics              0.7704
#     machines              0.7633
#     microcomputer         0.7579
#     emulation             0.7540
#     virtual               0.7527
#
#   Nearest neighbours of 'music':
#     musical               0.8682
#     jazz                  0.8368
#     musicians             0.8218
#     techno                0.8080
#     folk                  0.7937
#     instrumental          0.7931
#     recordings            0.7867
#     concert               0.7835
#
#
# =======================================================
# ANALOGY ACCURACY EVALUATION
# =======================================================
#
#   Accuracy : 198/9310 = 2.1%
#   Skipped  : 10234 (words not in vocabulary)
